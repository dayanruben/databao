# %%
import os

from dotenv import load_dotenv

os.chdir("..")


load_dotenv()

# %%
import logging

import pandas as pd
from sqlalchemy import create_engine

import databao

logging.basicConfig(level=logging.INFO)

# %%
engine = create_engine(
    "postgresql://readonly_role:>sU9y95R(e4m@ep-young-breeze-a5cq8xns.us-east-2.aws.neon.tech/netflix?options=endpoint%3Dep-young-breeze-a5cq8xns&sslmode=require"
)

# %%
pd.read_sql("SELECT * FROM netflix_shows WHERE country = 'Germany'", engine)

# %%
session = databao.open_session("my_session")
session.add_db(engine)

# %%
data = {"show_id": ["s706", "s1032", "s1253"], "cancelled": [True, True, False]}
df = pd.DataFrame(data)
df

# %%
session.add_df(df)

# %%
thread = session.thread()
thread.ask("list directors of cancelled shows").df()

# %%
result = thread.ask("How did you deduce the show was cancelled?")

# %%
str(result)
